# %% [markdown]
# # FULL STACK DATASCEINCE, AI, GENERATIVE AI -- 8AM -- 19th Feb 24

# %% [markdown]
# ![image.png](attachment:4ced7145-c10f-4497-a262-01601dd5661e.png)

# %%
'welcome to anaconda installation'
# Out:
# 'welcome to anaconda installation'

# %%
msg = 'welcome to anaconda installation'
msg
# Out:
# 'welcome to anaconda installation'

# %%
2 + 3
# Out:
# 5

# %%
_ + 4
# Out:
# 9

# %%
_ + 3
# Out:
# 12

# %%
5 + 5 - 3
# Out:
# 7

# %%
5 + ( 10 -3 )
# Out:
# 12

# %%
pi = 3.14
pi
# Out:
# 3.14

# %%
pi = 10.14
pi
# Out:
# 10.14

# %%
print('welcom to nit ')
# Out:
# welcom to nit

# %%
def greet(): # user define greet ()
    print('good morning') # good morning

# %%
def greet():
    print('good morning')
greet()
# Out:
# good morning

# %%
def greet():
    print('good morning')
greet()

greet()
# Out:
# good morning
# good morning

# %%
def greet():
    print('good morning')
greet()

greet()

greet()
# Out:
# good morning
# good morning
# good morning

# %%
import sys
sys.version
# Out:
# '3.11.7 | packaged by Anaconda, Inc. | (main, Dec 15 2023, 18:05:47) [MSC v.1916 64 bit (AMD64)]'

# %% [markdown]
# # PYTHON IDENTIFIER == OBJECT == VARIBEL

# %% [raw]
# # VALID SYNTAX ==> i = 56
# # invalid ==> 56 = i

# %%
i = 56
i
# Out:
# 56

# %%
56 = i
# Out:
#   Cell In[2], line 1
#     56 = i
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
i
# Out:
# 56

# %%
NIT = 25
nit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 NIT = 25
# ----> 2 nit
#
# NameError: name 'nit' is not defined

# %%
NIT
# Out:
# 25

# %%
NiiT = 20
Niit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 NiiT = 20
# ----> 2 Niit
#
# NameError: name 'Niit' is not defined

# %%
nit@ = 18
nit@
# Out:
#   Cell In[7], line 1
#     nit@ = 18
#          ^
# SyntaxError: invalid syntax

# %%
nit$ = 67
# Out:
#   Cell In[8], line 1
#     nit$ = 67
#        ^
# SyntaxError: invalid syntax

# %%
hi_ = 78
hi_
# Out:
# 78

# %%
x_train = 67
x_train
# Out:
# 67

# %%
1nit = 78
1nit
# Out:
#   Cell In[11], line 1
#     1nit = 78
#     ^
# SyntaxError: invalid decimal literal

# %%
nit1 = 78
nit1
# Out:
# 78

# %%
if = 67
if
# Out:
#   Cell In[13], line 1
#     if = 67
#        ^
# SyntaxError: invalid syntax

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
IF = 67
IF
# Out:
# 67

# %%
else = 67
else
# Out:
#   Cell In[17], line 1
#     else = 67
#     ^
# SyntaxError: invalid syntax

# %%
ELSE = 67
ELSE
# Out:
# 67

# %%
a = true 
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 a = true
#       2 a
#
# NameError: name 'true' is not defined

# %%
a = True
a
# Out:
# True

# %%
True + False + True
# Out:
# 2

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
True * True * False * True
# Out:
# 0

# %%
aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa = 90

# %%
aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
# Out:
# 90

# %%
aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
#
# NameError: name 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa' is not defined

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
nit1
# Out:
# 78

# %%
del nit1

# %%
nit1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 nit1
#
# NameError: name 'nit1' is not defined

# %%
_train = 90
_train
# Out:
# 90

# %%
1hi = 'nit'
1hi
# Out:
#   Cell In[35], line 1
#     1hi = 'nit'
#     ^
# SyntaxError: invalid decimal literal

# %%
hi1 = 'fine'
hi1
# Out:
# 'fine'

# %%
def = 90
def
# Out:
#   Cell In[37], line 1
#     def = 90
#         ^
# SyntaxError: invalid syntax

# %%
def greet():
    print('welcom')
greet()
# Out:
# welcom

# %%
a
# Out:
# True

# %%
a = 25
a
# Out:
# 25

# %%
id(a)
# Out:
# 140733821404712

# %%
b = 25
id(b)
# Out:
# 140733821404712

# %%
a = b

# %%
a == b
# Out:
# True

# %%
a != b
# Out:
# False

# %%
c = 56
c
# Out:
# 56

# %%
a != c
# Out:
# True

# %%
a != c
# Out:
#   Cell In[49], line 1
#     a ! = c
#       ^
# SyntaxError: invalid syntax

# %%
2 + 3
# Out:
# 5

# %%
a = 2
b = 3
c = a + b
print(c)
# Out:
# 5

# %%
nit1t = 8

# %%
1nit = 9
# Out:
#   Cell In[53], line 1
#     1nit = 9
#     ^
# SyntaxError: invalid decimal literal

# %%
True
# Out:
# True

# %%
True + True
# Out:
# 2

# %%
int(True)
# Out:
# 1

# %% [markdown]
# # PYTHON DATA TYPE
# 1- INT - value without decimal
# 2- FLOAT
# 3- COMPLEX
# 4- BOOL
# 5- STRING

# %% [markdown]
# # INT

# %%
i = 45
i
# Out:
# 45

# %%
type(i)
# Out:
# int

# %%
45 = i
# Out:
#   Cell In[63], line 1
#     45 = i
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
i
# Out:
# 45

# %%
1i = 34
# Out:
#   Cell In[65], line 1
#     1i = 34
#     ^
# SyntaxError: invalid decimal literal

# %%
i1 = 34
I1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 i1 = 34
# ----> 2 I1
#
# NameError: name 'I1' is not defined

# %%
i2 = 40
i3 = 50
i4 = 60

# %%
i, i1, i2, i3, i4
# Out:
# (45, 34, 40, 50, 60)

# %%
print(i)
print(i1)
print(i2)
print(i3)
print(i4)
# Out:
# 45
# 34
# 40
# 50
# 60

# %%
type(i2)
# Out:
# int

# %% [markdown]
# # FLOAT

# %%
f = 2.3
f
# Out:
# 2.3

# %%
type(f)
# Out:
# float

# %%
f = 1e0
f
# Out:
# 1.0

# %%
f1 = 1e1
f1
# Out:
# 10.0

# %%
f2 = 1e2
f2
# Out:
# 100.0

# %%
f3 = 2.4e3
f3
# Out:
# 2400.0

# %%
f4 = 2.4E2
f4
# Out:
# 240.0

# %% [markdown]
# # COMPLEX  ==>
# - a + bj  ( a  real part  | b - imaginary part | j is mat squrar root of -1)

# %%
c = 1 + 2j 
c
# Out:
# (1+2j)

# %%
type(c)
# Out:
# complex

# %%
id(c)
# Out:
# 1965513453232

# %%
c.real
# Out:
# 1.0

# %%
c.imaginary
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 c.imaginary
#
# AttributeError: 'complex' object has no attribute 'imaginary'

# %%
c.imag
# Out:
# 2.0

# %%
d = 2 + 3j

# %%
print(c)
print(d)
# Out:
# (1+2j)
# (2+3j)

# %%
c
d
c
# Out:
# (1+2j)

# %%
c, d
# Out:
# ((1+2j), (2+3j))

# %%
print(c,d)
# Out:
# (1+2j) (2+3j)

# %%
c + d
# Out:
# (3+5j)

# %%
c - d
# Out:
# (-1-1j)

# %%
c1 = 3.4 + 2.4j
c1
# Out:
# (3.4+2.4j)

# %%
c2 = 5 + 2.4j
c2
# Out:
# (5+2.4j)

# %% [markdown]
# # BOOL

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
b = True
b
# Out:
# True

# %%
b1 = False
b1
# Out:
# False

# %%
b2 = True + False 
b2
# Out:
# 1

# %%
b + b1
# Out:
# 1

# %%
b - b1
# Out:
# 1

# %%
b * b1
# Out:
# 0

# %%
b / b1
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 b / b1
#
# ZeroDivisionError: division by zero

# %%
b
# Out:
# True

# %%
b1
# Out:
# False

# %%
b1 / b # float division
# Out:
# 0.0

# %%
b1 // b # int divison
# Out:
# 0

# %%
12 / 5
# Out:
# 2.4

# %%
12 // 5
# Out:
# 2

# %%
12 % 3
# Out:
# 0

# %%
2 ** 2
# Out:
# 4

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# # STRING
# string alwaws assined  ' ' || " " | ''' '''

# %%
s = 'nit'
s
# Out:
# 'nit'

# %%
s1 = "niit"
s1
# Out:
# 'niit'

# %%
s3 = '''niiit'''
s3
# Out:
# 'niiit'

# %%
s4 = ' nit
        nit '
s4
# Out:
#   Cell In[123], line 1
#     s4 = ' nit
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s5 = " niit
        niit ""
s5
# Out:
#   Cell In[124], line 1
#     s5 = " niit
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s6 = ''' niiit
            niit'''
s6
# Out:
# ' niiit\n            niit'

# %%
text = '''ChatGPT is a chatbot developed by OpenAI and 
launched on November 30, 2022. Based on a large language model, 
it enables users to refine and steer a conversation 
towards a desired length, format, style'''

# %%
text
# Out:
# 'ChatGPT is a chatbot developed by OpenAI and \nlaunched on November 30, 2022. Based on a large language model, \nit enables users to refine and steer a conversation \ntowards a desired length, format, style'

# %% [markdown]
# #  PYTHON DATA TYPE WE COMPLETED

# %% [markdown]
# # PYTHON TYPE CASTING OR TYPE COVERSION
# 1- CONVERT OTHER DATATYPES TO INT
# 2- CONVERT OTHER DATATYPS TO FLOAT
# 3- CONVERT OTHER DATATYPS TO COMPLEX
# 4- CONVERT OTHER DATATYPS TO BOOL
# 5- CONVERT OTHER DATATYPS TO STRINT

# %%
int(2.3) #cast float to int
# Out:
# 2

# %%
int(2.3, 3.4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 int(2.3, 3.4)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(3.4)
# Out:
# 3

# %%
int(True)  # bool to int
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(1+2j) # complex we canto casting to int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
a, b, c, d, e = 5, 3.4, 'nit', 1+2j, True

# %%
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# 5
# 3.4
# nit
# (1+2j)
# True

# %%
print(int(2.3)) # float to int
print(int(True)) # bool to int
print(int('10')) #string to int
print(int(2+3j)) #complex to int
# Out:
# 2
# 1
# 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 print(int(True)) # bool to int
#       3 print(int('10')) #string to int
# ----> 4 print(int(2+3j))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %% [markdown]
# # CAST OTHER DATATYPE TO FLOAT

# %%
float(2)
# Out:
# 2.0

# %%
float(False)
# Out:
# 0.0

# %%
float('10')
# Out:
# 10.0

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %% [markdown]
# # cast other data type to complex

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10, 20)
# Out:
# (10+20j)

# %%
compelx(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 compelx(10,20,30)
#
# NameError: name 'compelx' is not defined

# %%
complex(3.4)
# Out:
# (3.4+0j)

# %%
complex(3.4, True)
# Out:
# (3.4+1j)

# %%
complex(3.4, 2.5)
# Out:
# (3.4+2.5j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(True, FALSE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 complex(True, FALSE)
#
# NameError: name 'FALSE' is not defined

# %%
complex(True, False)
# Out:
# (1+0j)

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('10', '20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 complex('10', '20')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex('10', 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 complex('10', 20)
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(10, '20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 complex(10, '20')
#
# TypeError: complex() second arg can't be a string

# %% [markdown]
# # cast other datatype to bool

# %%
bool(2)
# Out:
# True

# %%
bool(2.3)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool()
# Out:
# False

# %%
bool( )
# Out:
# False

# %%
bool('0')
# Out:
# True

# %%
bool('10')
# Out:
# True

# %% [markdown]
# # casting other datatype to string

# %%
str(2)
# Out:
# '2'

# %%
str(3)
# Out:
# '3'

# %%
str(3.4)
# Out:
# '3.4'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %%
str('0')
# Out:
# '0'

# %% [markdown]
# # STRING INDEXING

# %%
si = 'NARESH IT'
si
# Out:
# 'NARESH IT'

# %%
si[0]
# Out:
# 'N'

# %%
si[-3]
# Out:
# ' '

# %%
si[5]
# Out:
# 'H'

# %%
si
# Out:
# 'NARESH IT'

# %%
si[11]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 si[11]
#
# IndexError: string index out of range

# %%
si
# Out:
# 'NARESH IT'

# %%
si[0:7]
# Out:
# 'NARESH '

# %%
si
# Out:
# 'NARESH IT'

# %%
si1 = 'BASICPYTHON'

# %%
si1
# Out:
# 'BASICPYTHON'

# %%
si1[1:5]
# Out:
# 'ASIC'

# %%
si
# Out:
# 'NARESH IT'

# %%
si1
# Out:
# 'BASICPYTHON'

# %%
si +  si1
# Out:
# 'NARESH ITBASICPYTHON'

# %%
fl1 = np.nan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 fl1 = np.nan
#
# NameError: name 'np' is not defined
